# %%
import random as rd
import sys

def sys_chs():
    chs = {
        1: "rock",
        2: "paper",
        3: "scissor"
    }
    
    x = rd .choice(list(chs.keys()))
    return x



print("""This is Rock Paper Scissor game played between user and computer chose your option to continue
1 for Play
2 for exit""")
a = int(input("Enter your choise"))

if a == 1:
    print("Game started")
else:
    sys.exit()
    
i = 0
j = 0
while True:
    print("""Enter your choice
    1. for Rock
    2. for Paper
    3. for Scissor
    4. for quiting the game""")
    a = int(input())
    z = sys_chs()
    if a == 4:
        break
    elif a == z:
        print("you both chossed same")
    elif (a == 1 and z == 2) or (a == 2 and z == 3) or (a == 3 and z==1):
        print(f"You lose system {z}")
        j += 1
    elif (a == 1 and z == 3) or (a == 2 and z == 1) or (a == 3 and z == 2):
        print(f"You won system chosed {z}")
        i += 1
    else:
        print("please enter something between 1 to 4")
if i > j:
    print(f"You have won from the computer your have scored {i} and the computer scored{j}")
elif i == j:
    print(f"There is tie between you and computer your have scored {i} and the computer scored{j}")
else:
    print(f"You have lossed laugh on you 😂😂😂😂 you have scored {i} while computer have scored {j}")
# Out:
# This is Rock Paper Scissor game played between user and computer chose your option to continue
# 1 for Play
# 2 for exit
# Enter your choise1
# Game started
# Enter your choice
#     1. for Rock
#     2. for Paper
#     3. for Scissor
#     4. for quiting the game
# 1
# You won system chosed 3
# Enter your choice
#     1. for Rock
#     2. for Paper
#     3. for Scissor
#     4. for quiting the game
# 2
# You lose system 3
# Enter your choice
#     1. for Rock
#     2. for Paper
#     3. for Scissor
#     4. for quiting the game
# 3
# you both chossed same
# Enter your choice
#     1. for Rock
#     2. for Paper
#     3. for Scissor
#     4. for quiting the game
# 1
# You won system chosed 3
# Enter your choice
#     1. for Rock
#     2. for Paper
#     3. for Scissor
#     4. for quiting the game
# 2
# You lose system 3
# Enter your choice
#     1. for Rock
#     2. for Paper
#     3. for Scissor
#     4. for quiting the game
# 3
# You lose system 1
# Enter your choice
# ...
